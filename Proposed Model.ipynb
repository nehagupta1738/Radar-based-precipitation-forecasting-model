# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 62.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 23.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 69.5 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 79.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.6.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.15.1 safetensors-0.3.1 tokenizers-0.13.3 transformers-4.30.2

# %%
import numpy as np
import tensorflow as tf
import keras
import tensorflow_probability as tfp
from tensorflow.keras.layers import Input, Dense, Reshape, UpSampling2D, Conv2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from transformers import LongformerModel
from sklearn.preprocessing import MinMaxScaler

# %%
# Set the input and output shapes
INPUT_SHAPE = (128, 128, 4)  # Input shape of the model
OUTPUT_SHAPE = (128, 128, 1)  # Output shape of the model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
min_max = '/content/drive/MyDrive/example1/min_max_scale_new.npy'
min, max = np.load(min_max, encoding='bytes')
print(min, max)
# Out:
# -236.2857142857143 295.5714285714286

# %%
# Load and preprocess the data
def load_data(file_path):
    data = np.load(file_path)
    return data

def preprocess_data(file_list):
    # data = []
    # labels = []
    loaded_data = []
    for file_name in file_list:
        file_path = '/content/drive/MyDrive/example1/' + file_name
        loaded_data.append(load_data(file_path))
    return np.array(loaded_data)


def generate_data(data,min_train,max_train):
    # data shape=(n_samples, row, col, timesteps)
    n_samples=data.shape[0]
    time_step=data.shape[3]
    row=128
    col=128

    # replace the pixel of "no echo (-127)" as 0
    data[data<=-127]=0

    # for training dataset (t-30,t-20,t-10,t,1+10)
    n_frames=4
    movie_in=np.zeros((n_samples,row,col,n_frames))
    movie_out=np.zeros((n_samples,row,col,1))
    for i in range(n_samples):
        for j in range(n_frames):
            m_in=(255.*((data[i,::,::,j]+10.)/70.))+0.5
            movie_in[i,::,::,j]=m_in
        m_out=(255.*((data[i,::,::,-1]+10.)/70.))+0.5
        movie_out[i,::,::,0]=m_out

    # Min-max scaling
    movie_in=(movie_in-min_train)/(max_train-min_train)
    movie_out=(movie_out-min_train)/(max_train-min_train)

    return movie_in, movie_out

# %%
# Load the training and testing data
train_file_list = np.loadtxt('/content/drive/MyDrive/example1/radar_events_train.txt', dtype=str)
test_file_list = np.loadtxt('/content/drive/MyDrive/example1/radar_events_test.txt', dtype=str)

data_train = preprocess_data(train_file_list)
data_test = preprocess_data(test_file_list)


x_train, y_train = generate_data(data_train, min, max)
x_test, y_test = generate_data(data_test, min, max)

# %%
# Vision Transformer

image_size = 128
patch_size = 16
num_patches = (image_size//patch_size) **2

# hyper parameters for the ViT module
projection_dim = 64 # size of hidden dimension feature vectors in our model
                     # project patches into these 64-dimensional feature vectors that are concatenated together
                     # as input to encoder layer

num_heads = 8  #no. of heads in multi head attention layer, four separate transformations

# We are going to overriding the mlp layer to add a skip connection like resnet.
# In transformer, we have skip connection from the output of self attention and then it goes to feed
# forward layer that's going to compress the dimensionality and then you skip ahead with the previous output
# from the previous dense layer

#parametrization of the skip connection
transformer_units = [projection_dim*2,projection_dim]
#two stacked transformer layers
transformer_layers = 8
mlp_head_units = [4096,2048]  # Size of the dense layers of the final classifier
#custom MLP to add skip connection
def mlp(x, hidden_units, dropout_rate):
  for units in hidden_units:
    x = layers.Dense(units, activation=tf.nn.gelu)(x)
    x = layers.Dropout(dropout_rate)(x)
  return x                                                                                                                                                                                                    #overriding keras layer object to implement the patches layer
class Patches(layers.Layer):
    def __init__(self, patch_size, **kwargs):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def get_config(self):
      config = super().get_config()
      config.update({
          'patch_size': self.patch_size
      })
      return config


    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches                                                                                                                                                                               # The PatchEncoder layer will linearly transform a patch by projecting it into a
# vector of size projection_dim. In addition, it adds a learnable position
# embedding to the projected vector.
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, **kwargs):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def get_config(self):
      config = super().get_config()
      config.update({
          'num_patches': self.num_patches,
          'projection': self.projection,
          'position_embedding': self.position_embedding
      })
      return config

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded
def create_vit(inputs):
    # Create patches.
    patches = Patches(patch_size)(inputs)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches=num_patches, projection_dim=projection_dim)(patches)
    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    return encoded_patches

def create_model(input_shape):
    inputs = Input(shape=input_shape)

    # Split the input tensor into individual timestamps
    timestamps = tf.split(inputs, num_or_size_splits=4, axis=-1)

    llayers = []
    for timestamp in timestamps:
        timestamp = tf.reshape(timestamp, [-1, 128, 128, 1])
        llayers.append(create_vit(timestamp))

    vit = tf.stack(llayers, axis=-1)
    vit = tf.reshape(vit, (-1, 64, 64, 4))  # Reshape the ViT output to (None, 64, 64, 4)

    # Reshape the data to match LSTM input requirements
    reshaped_vit = Reshape(target_shape=(64*64, 4))(vit)

    lstm = layers.LSTM(128, input_shape=(64*64, 4), return_sequences=True)(reshaped_vit)
    # Upsampling decoder
    decoded = Reshape(target_shape=(64, 64, 128))(lstm)
    decoded = UpSampling2D(size=(2, 2))(decoded)
    output = Conv2D(1, (3, 3), activation='relu', padding='same')(decoded)

    model = Model(inputs=inputs, outputs=output)
    return model

input_shape = (128, 128, 4)
model = create_model(input_shape)
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 4  0           []
#                                 )]
#
#  tf.split (TFOpLambda)          [(None, 128, 128, 1  0           ['input_1[0][0]']
#                                 ),
#                                  (None, 128, 128, 1
#                                 ),
#                                  (None, 128, 128, 1
#                                 ),
#                                  (None, 128, 128, 1
#                                 )]
#
#  tf.reshape (TFOpLambda)        (None, 128, 128, 1)  0           ['tf.split[0][0]']
#
#  tf.reshape_1 (TFOpLambda)      (None, 128, 128, 1)  0           ['tf.split[0][1]']
#
#  tf.reshape_2 (TFOpLambda)      (None, 128, 128, 1)  0           ['tf.split[0][2]']
#
#  tf.reshape_3 (TFOpLambda)      (None, 128, 128, 1)  0           ['tf.split[0][3]']
#
#  patches (Patches)              (None, None, 256)    0           ['tf.reshape[0][0]']
#
#  patches_1 (Patches)            (None, None, 256)    0           ['tf.reshape_1[0][0]']
#
#  patches_2 (Patches)            (None, None, 256)    0           ['tf.reshape_2[0][0]']
#
#  patches_3 (Patches)            (None, None, 256)    0           ['tf.reshape_3[0][0]']
#
#  patch_encoder (PatchEncoder)   (None, 64, 64)       20544       ['patches[0][0]']
#
#  patch_encoder_1 (PatchEncoder)  (None, 64, 64)      20544       ['patches_1[0][0]']
#
#  patch_encoder_2 (PatchEncoder)  (None, 64, 64)      20544       ['patches_2[0][0]']
#
#  patch_encoder_3 (PatchEncoder)  (None, 64, 64)      20544       ['patches_3[0][0]']
#
#  layer_normalization (LayerNorm  (None, 64, 64)      128         ['patch_encoder[0][0]']
#  alization)
#
#  layer_normalization_16 (LayerN  (None, 64, 64)      128         ['patch_encoder_1[0][0]']
#  ormalization)
#
#  layer_normalization_32 (LayerN  (None, 64, 64)      128         ['patch_encoder_2[0][0]']
#  ormalization)
#
#  layer_normalization_48 (LayerN  (None, 64, 64)      128         ['patch_encoder_3[0][0]']
#  ormalization)
#
#  multi_head_attention (MultiHea  (None, 64, 64)      132672      ['layer_normalization[0][0]',
#  dAttention)                                                      'layer_normalization[0][0]']
#
#  multi_head_attention_8 (MultiH  (None, 64, 64)      132672      ['layer_normalization_16[0][0]',
#  eadAttention)                                                    'layer_normalization_16[0][0]']
#
#  multi_head_attention_16 (Multi  (None, 64, 64)      132672      ['layer_normalization_32[0][0]',
#  HeadAttention)                                                   'layer_normalization_32[0][0]']
#
#  multi_head_attention_24 (Multi  (None, 64, 64)      132672      ['layer_normalization_48[0][0]',
#  HeadAttention)                                                   'layer_normalization_48[0][0]']
#
#  add (Add)                      (None, 64, 64)       0           ['multi_head_attention[0][0]',
#                                                                   'patch_encoder[0][0]']
#
#  add_16 (Add)                   (None, 64, 64)       0           ['multi_head_attention_8[0][0]',
#                                                                   'patch_encoder_1[0][0]']
#
#  add_32 (Add)                   (None, 64, 64)       0           ['multi_head_attention_16[0][0]',
#                                                                   'patch_encoder_2[0][0]']
#
#  add_48 (Add)                   (None, 64, 64)       0           ['multi_head_attention_24[0][0]',
#                                                                   'patch_encoder_3[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 64, 64)      128         ['add[0][0]']
#  rmalization)
#
#  layer_normalization_17 (LayerN  (None, 64, 64)      128         ['add_16[0][0]']
#  ormalization)
#
#  layer_normalization_33 (LayerN  (None, 64, 64)      128         ['add_32[0][0]']
#  ormalization)
#
#  layer_normalization_49 (LayerN  (None, 64, 64)      128         ['add_48[0][0]']
#  ormalization)
#
#  dense_1 (Dense)                (None, 64, 128)      8320        ['layer_normalization_1[0][0]']
#
#  dense_18 (Dense)               (None, 64, 128)      8320        ['layer_normalization_17[0][0]']
#
#  dense_35 (Dense)               (None, 64, 128)      8320        ['layer_normalization_33[0][0]']
#
#  dense_52 (Dense)               (None, 64, 128)      8320        ['layer_normalization_49[0][0]']
#
#  dropout (Dropout)              (None, 64, 128)      0           ['dense_1[0][0]']
#
#  dropout_16 (Dropout)           (None, 64, 128)      0           ['dense_18[0][0]']
#
#  dropout_32 (Dropout)           (None, 64, 128)      0           ['dense_35[0][0]']
#
#  dropout_48 (Dropout)           (None, 64, 128)      0           ['dense_52[0][0]']
#
#  dense_2 (Dense)                (None, 64, 64)       8256        ['dropout[0][0]']
#
#  dense_19 (Dense)               (None, 64, 64)       8256        ['dropout_16[0][0]']
#
#  dense_36 (Dense)               (None, 64, 64)       8256        ['dropout_32[0][0]']
#
#  dense_53 (Dense)               (None, 64, 64)       8256        ['dropout_48[0][0]']
#
#  dropout_1 (Dropout)            (None, 64, 64)       0           ['dense_2[0][0]']
#
#  dropout_17 (Dropout)           (None, 64, 64)       0           ['dense_19[0][0]']
#
#  dropout_33 (Dropout)           (None, 64, 64)       0           ['dense_36[0][0]']
#
#  dropout_49 (Dropout)           (None, 64, 64)       0           ['dense_53[0][0]']
#
#  add_1 (Add)                    (None, 64, 64)       0           ['dropout_1[0][0]',
#                                                                   'add[0][0]']
#
#  add_17 (Add)                   (None, 64, 64)       0           ['dropout_17[0][0]',
#                                                                   'add_16[0][0]']
#
#  add_33 (Add)                   (None, 64, 64)       0           ['dropout_33[0][0]',
#                                                                   'add_32[0][0]']
#
#  add_49 (Add)                   (None, 64, 64)       0           ['dropout_49[0][0]',
#                                                                   'add_48[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 64, 64)      128         ['add_1[0][0]']
#  rmalization)
#
#  layer_normalization_18 (LayerN  (None, 64, 64)      128         ['add_17[0][0]']
#  ormalization)
#
#  layer_normalization_34 (LayerN  (None, 64, 64)      128         ['add_33[0][0]']
#  ormalization)
#
#  layer_normalization_50 (LayerN  (None, 64, 64)      128         ['add_49[0][0]']
#  ormalization)
#
#  multi_head_attention_1 (MultiH  (None, 64, 64)      132672      ['layer_normalization_2[0][0]',
#  eadAttention)                                                    'layer_normalization_2[0][0]']
#
#  multi_head_attention_9 (MultiH  (None, 64, 64)      132672      ['layer_normalization_18[0][0]',
#  eadAttention)                                                    'layer_normalization_18[0][0]']
#
#  multi_head_attention_17 (Multi  (None, 64, 64)      132672      ['layer_normalization_34[0][0]',
#  HeadAttention)                                                   'layer_normalization_34[0][0]']
#
#  multi_head_attention_25 (Multi  (None, 64, 64)      132672      ['layer_normalization_50[0][0]',
#  HeadAttention)                                                   'layer_normalization_50[0][0]']
#
#  add_2 (Add)                    (None, 64, 64)       0           ['multi_head_attention_1[0][0]',
#                                                                   'add_1[0][0]']
#
#  add_18 (Add)                   (None, 64, 64)       0           ['multi_head_attention_9[0][0]',
#                                                                   'add_17[0][0]']
#
#  add_34 (Add)                   (None, 64, 64)       0           ['multi_head_attention_17[0][0]',
#                                                                   'add_33[0][0]']
#
#  add_50 (Add)                   (None, 64, 64)       0           ['multi_head_attention_25[0][0]',
#                                                                   'add_49[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 64, 64)      128         ['add_2[0][0]']
#  rmalization)
#
#  layer_normalization_19 (LayerN  (None, 64, 64)      128         ['add_18[0][0]']
#  ormalization)
#
#  layer_normalization_35 (LayerN  (None, 64, 64)      128         ['add_34[0][0]']
#  ormalization)
#
#  layer_normalization_51 (LayerN  (None, 64, 64)      128         ['add_50[0][0]']
#  ormalization)
#
#  dense_3 (Dense)                (None, 64, 128)      8320        ['layer_normalization_3[0][0]']
#
#  dense_20 (Dense)               (None, 64, 128)      8320        ['layer_normalization_19[0][0]']
#
#  dense_37 (Dense)               (None, 64, 128)      8320        ['layer_normalization_35[0][0]']
#
#  dense_54 (Dense)               (None, 64, 128)      8320        ['layer_normalization_51[0][0]']
#
#  dropout_2 (Dropout)            (None, 64, 128)      0           ['dense_3[0][0]']
#
#  dropout_18 (Dropout)           (None, 64, 128)      0           ['dense_20[0][0]']
#
#  dropout_34 (Dropout)           (None, 64, 128)      0           ['dense_37[0][0]']
#
#  dropout_50 (Dropout)           (None, 64, 128)      0           ['dense_54[0][0]']
#
#  dense_4 (Dense)                (None, 64, 64)       8256        ['dropout_2[0][0]']
#
#  dense_21 (Dense)               (None, 64, 64)       8256        ['dropout_18[0][0]']
#
#  dense_38 (Dense)               (None, 64, 64)       8256        ['dropout_34[0][0]']
#
#  dense_55 (Dense)               (None, 64, 64)       8256        ['dropout_50[0][0]']
#
#  dropout_3 (Dropout)            (None, 64, 64)       0           ['dense_4[0][0]']
#
#  dropout_19 (Dropout)           (None, 64, 64)       0           ['dense_21[0][0]']
#
#  dropout_35 (Dropout)           (None, 64, 64)       0           ['dense_38[0][0]']
#
#  dropout_51 (Dropout)           (None, 64, 64)       0           ['dense_55[0][0]']
#
#  add_3 (Add)                    (None, 64, 64)       0           ['dropout_3[0][0]',
#                                                                   'add_2[0][0]']
#
#  add_19 (Add)                   (None, 64, 64)       0           ['dropout_19[0][0]',
#                                                                   'add_18[0][0]']
#
#  add_35 (Add)                   (None, 64, 64)       0           ['dropout_35[0][0]',
#                                                                   'add_34[0][0]']
#
#  add_51 (Add)                   (None, 64, 64)       0           ['dropout_51[0][0]',
#                                                                   'add_50[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 64, 64)      128         ['add_3[0][0]']
#  rmalization)
#
#  layer_normalization_20 (LayerN  (None, 64, 64)      128         ['add_19[0][0]']
#  ormalization)
#
#  layer_normalization_36 (LayerN  (None, 64, 64)      128         ['add_35[0][0]']
#  ormalization)
#
#  layer_normalization_52 (LayerN  (None, 64, 64)      128         ['add_51[0][0]']
#  ormalization)
#
#  multi_head_attention_2 (MultiH  (None, 64, 64)      132672      ['layer_normalization_4[0][0]',
#  eadAttention)                                                    'layer_normalization_4[0][0]']
#
#  multi_head_attention_10 (Multi  (None, 64, 64)      132672      ['layer_normalization_20[0][0]',
#  HeadAttention)                                                   'layer_normalization_20[0][0]']
#
#  multi_head_attention_18 (Multi  (None, 64, 64)      132672      ['layer_normalization_36[0][0]',
#  HeadAttention)                                                   'layer_normalization_36[0][0]']
#
#  multi_head_attention_26 (Multi  (None, 64, 64)      132672      ['layer_normalization_52[0][0]',
#  HeadAttention)                                                   'layer_normalization_52[0][0]']
#
#  add_4 (Add)                    (None, 64, 64)       0           ['multi_head_attention_2[0][0]',
#                                                                   'add_3[0][0]']
#
#  add_20 (Add)                   (None, 64, 64)       0           ['multi_head_attention_10[0][0]',
#                                                                   'add_19[0][0]']
#
#  add_36 (Add)                   (None, 64, 64)       0           ['multi_head_attention_18[0][0]',
#                                                                   'add_35[0][0]']
#
#  add_52 (Add)                   (None, 64, 64)       0           ['multi_head_attention_26[0][0]',
#                                                                   'add_51[0][0]']
#
#  layer_normalization_5 (LayerNo  (None, 64, 64)      128         ['add_4[0][0]']
#  rmalization)
#
#  layer_normalization_21 (LayerN  (None, 64, 64)      128         ['add_20[0][0]']
#  ormalization)
#
#  layer_normalization_37 (LayerN  (None, 64, 64)      128         ['add_36[0][0]']
#  ormalization)
#
#  layer_normalization_53 (LayerN  (None, 64, 64)      128         ['add_52[0][0]']
#  ormalization)
#
#  dense_5 (Dense)                (None, 64, 128)      8320        ['layer_normalization_5[0][0]']
#
#  dense_22 (Dense)               (None, 64, 128)      8320        ['layer_normalization_21[0][0]']
#
#  dense_39 (Dense)               (None, 64, 128)      8320        ['layer_normalization_37[0][0]']
#
#  dense_56 (Dense)               (None, 64, 128)      8320        ['layer_normalization_53[0][0]']
#
#  dropout_4 (Dropout)            (None, 64, 128)      0           ['dense_5[0][0]']
#
#  dropout_20 (Dropout)           (None, 64, 128)      0           ['dense_22[0][0]']
#
#  dropout_36 (Dropout)           (None, 64, 128)      0           ['dense_39[0][0]']
#
#  dropout_52 (Dropout)           (None, 64, 128)      0           ['dense_56[0][0]']
#
#  dense_6 (Dense)                (None, 64, 64)       8256        ['dropout_4[0][0]']
#
#  dense_23 (Dense)               (None, 64, 64)       8256        ['dropout_20[0][0]']
#
#  dense_40 (Dense)               (None, 64, 64)       8256        ['dropout_36[0][0]']
#
#  dense_57 (Dense)               (None, 64, 64)       8256        ['dropout_52[0][0]']
#
#  dropout_5 (Dropout)            (None, 64, 64)       0           ['dense_6[0][0]']
#
#  dropout_21 (Dropout)           (None, 64, 64)       0           ['dense_23[0][0]']
#
#  dropout_37 (Dropout)           (None, 64, 64)       0           ['dense_40[0][0]']
#
#  dropout_53 (Dropout)           (None, 64, 64)       0           ['dense_57[0][0]']
#
#  add_5 (Add)                    (None, 64, 64)       0           ['dropout_5[0][0]',
#                                                                   'add_4[0][0]']
#
#  add_21 (Add)                   (None, 64, 64)       0           ['dropout_21[0][0]',
#                                                                   'add_20[0][0]']
#
#  add_37 (Add)                   (None, 64, 64)       0           ['dropout_37[0][0]',
#                                                                   'add_36[0][0]']
#
#  add_53 (Add)                   (None, 64, 64)       0           ['dropout_53[0][0]',
#                                                                   'add_52[0][0]']
#
#  layer_normalization_6 (LayerNo  (None, 64, 64)      128         ['add_5[0][0]']
#  rmalization)
#
#  layer_normalization_22 (LayerN  (None, 64, 64)      128         ['add_21[0][0]']
#  ormalization)
#
#  layer_normalization_38 (LayerN  (None, 64, 64)      128         ['add_37[0][0]']
#  ormalization)
#
#  layer_normalization_54 (LayerN  (None, 64, 64)      128         ['add_53[0][0]']
#  ormalization)
#
#  multi_head_attention_3 (MultiH  (None, 64, 64)      132672      ['layer_normalization_6[0][0]',
#  eadAttention)                                                    'layer_normalization_6[0][0]']
#
#  multi_head_attention_11 (Multi  (None, 64, 64)      132672      ['layer_normalization_22[0][0]',
#  HeadAttention)                                                   'layer_normalization_22[0][0]']
#
#  multi_head_attention_19 (Multi  (None, 64, 64)      132672      ['layer_normalization_38[0][0]',
#  HeadAttention)                                                   'layer_normalization_38[0][0]']
#
#  multi_head_attention_27 (Multi  (None, 64, 64)      132672      ['layer_normalization_54[0][0]',
#  HeadAttention)                                                   'layer_normalization_54[0][0]']
#
#  add_6 (Add)                    (None, 64, 64)       0           ['multi_head_attention_3[0][0]',
#                                                                   'add_5[0][0]']
#
#  add_22 (Add)                   (None, 64, 64)       0           ['multi_head_attention_11[0][0]',
#                                                                   'add_21[0][0]']
#
#  add_38 (Add)                   (None, 64, 64)       0           ['multi_head_attention_19[0][0]',
#                                                                   'add_37[0][0]']
#
#  add_54 (Add)                   (None, 64, 64)       0           ['multi_head_attention_27[0][0]',
#                                                                   'add_53[0][0]']
#
#  layer_normalization_7 (LayerNo  (None, 64, 64)      128         ['add_6[0][0]']
#  rmalization)
#
#  layer_normalization_23 (LayerN  (None, 64, 64)      128         ['add_22[0][0]']
#  ormalization)
#
#  layer_normalization_39 (LayerN  (None, 64, 64)      128         ['add_38[0][0]']
#  ormalization)
#
#  layer_normalization_55 (LayerN  (None, 64, 64)      128         ['add_54[0][0]']
#  ormalization)
#
#  dense_7 (Dense)                (None, 64, 128)      8320        ['layer_normalization_7[0][0]']
#
#  dense_24 (Dense)               (None, 64, 128)      8320        ['layer_normalization_23[0][0]']
#
#  dense_41 (Dense)               (None, 64, 128)      8320        ['layer_normalization_39[0][0]']
#
#  dense_58 (Dense)               (None, 64, 128)      8320        ['layer_normalization_55[0][0]']
#
#  dropout_6 (Dropout)            (None, 64, 128)      0           ['dense_7[0][0]']
#
#  dropout_22 (Dropout)           (None, 64, 128)      0           ['dense_24[0][0]']
#
#  dropout_38 (Dropout)           (None, 64, 128)      0           ['dense_41[0][0]']
#
#  dropout_54 (Dropout)           (None, 64, 128)      0           ['dense_58[0][0]']
#
#  dense_8 (Dense)                (None, 64, 64)       8256        ['dropout_6[0][0]']
#
#  dense_25 (Dense)               (None, 64, 64)       8256        ['dropout_22[0][0]']
#
#  dense_42 (Dense)               (None, 64, 64)       8256        ['dropout_38[0][0]']
#
#  dense_59 (Dense)               (None, 64, 64)       8256        ['dropout_54[0][0]']
#
#  dropout_7 (Dropout)            (None, 64, 64)       0           ['dense_8[0][0]']
#
#  dropout_23 (Dropout)           (None, 64, 64)       0           ['dense_25[0][0]']
#
#  dropout_39 (Dropout)           (None, 64, 64)       0           ['dense_42[0][0]']
#
#  dropout_55 (Dropout)           (None, 64, 64)       0           ['dense_59[0][0]']
#
#  add_7 (Add)                    (None, 64, 64)       0           ['dropout_7[0][0]',
#                                                                   'add_6[0][0]']
#
#  add_23 (Add)                   (None, 64, 64)       0           ['dropout_23[0][0]',
#                                                                   'add_22[0][0]']
#
#  add_39 (Add)                   (None, 64, 64)       0           ['dropout_39[0][0]',
#                                                                   'add_38[0][0]']
#
#  add_55 (Add)                   (None, 64, 64)       0           ['dropout_55[0][0]',
#                                                                   'add_54[0][0]']
#
#  layer_normalization_8 (LayerNo  (None, 64, 64)      128         ['add_7[0][0]']
#  rmalization)
#
#  layer_normalization_24 (LayerN  (None, 64, 64)      128         ['add_23[0][0]']
#  ormalization)
#
#  layer_normalization_40 (LayerN  (None, 64, 64)      128         ['add_39[0][0]']
#  ormalization)
#
#  layer_normalization_56 (LayerN  (None, 64, 64)      128         ['add_55[0][0]']
#  ormalization)
#
#  multi_head_attention_4 (MultiH  (None, 64, 64)      132672      ['layer_normalization_8[0][0]',
#  eadAttention)                                                    'layer_normalization_8[0][0]']
#
#  multi_head_attention_12 (Multi  (None, 64, 64)      132672      ['layer_normalization_24[0][0]',
#  HeadAttention)                                                   'layer_normalization_24[0][0]']
#
#  multi_head_attention_20 (Multi  (None, 64, 64)      132672      ['layer_normalization_40[0][0]',
#  HeadAttention)                                                   'layer_normalization_40[0][0]']
#
#  multi_head_attention_28 (Multi  (None, 64, 64)      132672      ['layer_normalization_56[0][0]',
#  HeadAttention)                                                   'layer_normalization_56[0][0]']
#
#  add_8 (Add)                    (None, 64, 64)       0           ['multi_head_attention_4[0][0]',
#                                                                   'add_7[0][0]']
#
#  add_24 (Add)                   (None, 64, 64)       0           ['multi_head_attention_12[0][0]',
#                                                                   'add_23[0][0]']
#
#  add_40 (Add)                   (None, 64, 64)       0           ['multi_head_attention_20[0][0]',
#                                                                   'add_39[0][0]']
#
#  add_56 (Add)                   (None, 64, 64)       0           ['multi_head_attention_28[0][0]',
#                                                                   'add_55[0][0]']
#
#  layer_normalization_9 (LayerNo  (None, 64, 64)      128         ['add_8[0][0]']
#  rmalization)
#
#  layer_normalization_25 (LayerN  (None, 64, 64)      128         ['add_24[0][0]']
#  ormalization)
#
#  layer_normalization_41 (LayerN  (None, 64, 64)      128         ['add_40[0][0]']
#  ormalization)
#
#  layer_normalization_57 (LayerN  (None, 64, 64)      128         ['add_56[0][0]']
#  ormalization)
#
#  dense_9 (Dense)                (None, 64, 128)      8320        ['layer_normalization_9[0][0]']
#
#  dense_26 (Dense)               (None, 64, 128)      8320        ['layer_normalization_25[0][0]']
#
#  dense_43 (Dense)               (None, 64, 128)      8320        ['layer_normalization_41[0][0]']
#
#  dense_60 (Dense)               (None, 64, 128)      8320        ['layer_normalization_57[0][0]']
#
#  dropout_8 (Dropout)            (None, 64, 128)      0           ['dense_9[0][0]']
#
#  dropout_24 (Dropout)           (None, 64, 128)      0           ['dense_26[0][0]']
#
#  dropout_40 (Dropout)           (None, 64, 128)      0           ['dense_43[0][0]']
#
#  dropout_56 (Dropout)           (None, 64, 128)      0           ['dense_60[0][0]']
#
#  dense_10 (Dense)               (None, 64, 64)       8256        ['dropout_8[0][0]']
#
#  dense_27 (Dense)               (None, 64, 64)       8256        ['dropout_24[0][0]']
#
#  dense_44 (Dense)               (None, 64, 64)       8256        ['dropout_40[0][0]']
#
#  dense_61 (Dense)               (None, 64, 64)       8256        ['dropout_56[0][0]']
#
#  dropout_9 (Dropout)            (None, 64, 64)       0           ['dense_10[0][0]']
#
#  dropout_25 (Dropout)           (None, 64, 64)       0           ['dense_27[0][0]']
#
#  dropout_41 (Dropout)           (None, 64, 64)       0           ['dense_44[0][0]']
# ...
#
#  layer_normalization_61 (LayerN  (None, 64, 64)      128         ['add_60[0][0]']
#  ormalization)
#
#  dense_13 (Dense)               (None, 64, 128)      8320        ['layer_normalization_13[0][0]']
#
#  dense_30 (Dense)               (None, 64, 128)      8320        ['layer_normalization_29[0][0]']
#
#  dense_47 (Dense)               (None, 64, 128)      8320        ['layer_normalization_45[0][0]']
#
#  dense_64 (Dense)               (None, 64, 128)      8320        ['layer_normalization_61[0][0]']
#
#  dropout_12 (Dropout)           (None, 64, 128)      0           ['dense_13[0][0]']
#
#  dropout_28 (Dropout)           (None, 64, 128)      0           ['dense_30[0][0]']
#
#  dropout_44 (Dropout)           (None, 64, 128)      0           ['dense_47[0][0]']
#
#  dropout_60 (Dropout)           (None, 64, 128)      0           ['dense_64[0][0]']
#
#  dense_14 (Dense)               (None, 64, 64)       8256        ['dropout_12[0][0]']
#
#  dense_31 (Dense)               (None, 64, 64)       8256        ['dropout_28[0][0]']
#
#  dense_48 (Dense)               (None, 64, 64)       8256        ['dropout_44[0][0]']
#
#  dense_65 (Dense)               (None, 64, 64)       8256        ['dropout_60[0][0]']
#
#  dropout_13 (Dropout)           (None, 64, 64)       0           ['dense_14[0][0]']
#
#  dropout_29 (Dropout)           (None, 64, 64)       0           ['dense_31[0][0]']
#
#  dropout_45 (Dropout)           (None, 64, 64)       0           ['dense_48[0][0]']
#
#  dropout_61 (Dropout)           (None, 64, 64)       0           ['dense_65[0][0]']
#
#  add_13 (Add)                   (None, 64, 64)       0           ['dropout_13[0][0]',
#                                                                   'add_12[0][0]']
#
#  add_29 (Add)                   (None, 64, 64)       0           ['dropout_29[0][0]',
#                                                                   'add_28[0][0]']
#
#  add_45 (Add)                   (None, 64, 64)       0           ['dropout_45[0][0]',
#                                                                   'add_44[0][0]']
#
#  add_61 (Add)                   (None, 64, 64)       0           ['dropout_61[0][0]',
#                                                                   'add_60[0][0]']
#
#  layer_normalization_14 (LayerN  (None, 64, 64)      128         ['add_13[0][0]']
#  ormalization)
#
#  layer_normalization_30 (LayerN  (None, 64, 64)      128         ['add_29[0][0]']
#  ormalization)
#
#  layer_normalization_46 (LayerN  (None, 64, 64)      128         ['add_45[0][0]']
#  ormalization)
#
#  layer_normalization_62 (LayerN  (None, 64, 64)      128         ['add_61[0][0]']
#  ormalization)
#
#  multi_head_attention_7 (MultiH  (None, 64, 64)      132672      ['layer_normalization_14[0][0]',
#  eadAttention)                                                    'layer_normalization_14[0][0]']
#
#  multi_head_attention_15 (Multi  (None, 64, 64)      132672      ['layer_normalization_30[0][0]',
#  HeadAttention)                                                   'layer_normalization_30[0][0]']
#
#  multi_head_attention_23 (Multi  (None, 64, 64)      132672      ['layer_normalization_46[0][0]',
#  HeadAttention)                                                   'layer_normalization_46[0][0]']
#
#  multi_head_attention_31 (Multi  (None, 64, 64)      132672      ['layer_normalization_62[0][0]',
#  HeadAttention)                                                   'layer_normalization_62[0][0]']
#
#  add_14 (Add)                   (None, 64, 64)       0           ['multi_head_attention_7[0][0]',
#                                                                   'add_13[0][0]']
#
#  add_30 (Add)                   (None, 64, 64)       0           ['multi_head_attention_15[0][0]',
#                                                                   'add_29[0][0]']
#
#  add_46 (Add)                   (None, 64, 64)       0           ['multi_head_attention_23[0][0]',
#                                                                   'add_45[0][0]']
#
#  add_62 (Add)                   (None, 64, 64)       0           ['multi_head_attention_31[0][0]',
#                                                                   'add_61[0][0]']
#
#  layer_normalization_15 (LayerN  (None, 64, 64)      128         ['add_14[0][0]']
#  ormalization)
#
#  layer_normalization_31 (LayerN  (None, 64, 64)      128         ['add_30[0][0]']
#  ormalization)
#
#  layer_normalization_47 (LayerN  (None, 64, 64)      128         ['add_46[0][0]']
#  ormalization)
#
#  layer_normalization_63 (LayerN  (None, 64, 64)      128         ['add_62[0][0]']
#  ormalization)
#
#  dense_15 (Dense)               (None, 64, 128)      8320        ['layer_normalization_15[0][0]']
#
#  dense_32 (Dense)               (None, 64, 128)      8320        ['layer_normalization_31[0][0]']
#
#  dense_49 (Dense)               (None, 64, 128)      8320        ['layer_normalization_47[0][0]']
#
#  dense_66 (Dense)               (None, 64, 128)      8320        ['layer_normalization_63[0][0]']
#
#  dropout_14 (Dropout)           (None, 64, 128)      0           ['dense_15[0][0]']
#
#  dropout_30 (Dropout)           (None, 64, 128)      0           ['dense_32[0][0]']
#
#  dropout_46 (Dropout)           (None, 64, 128)      0           ['dense_49[0][0]']
#
#  dropout_62 (Dropout)           (None, 64, 128)      0           ['dense_66[0][0]']
#
#  dense_16 (Dense)               (None, 64, 64)       8256        ['dropout_14[0][0]']
#
#  dense_33 (Dense)               (None, 64, 64)       8256        ['dropout_30[0][0]']
#
#  dense_50 (Dense)               (None, 64, 64)       8256        ['dropout_46[0][0]']
#
#  dense_67 (Dense)               (None, 64, 64)       8256        ['dropout_62[0][0]']
#
#  dropout_15 (Dropout)           (None, 64, 64)       0           ['dense_16[0][0]']
#
#  dropout_31 (Dropout)           (None, 64, 64)       0           ['dense_33[0][0]']
#
#  dropout_47 (Dropout)           (None, 64, 64)       0           ['dense_50[0][0]']
#
#  dropout_63 (Dropout)           (None, 64, 64)       0           ['dense_67[0][0]']
#
#  add_15 (Add)                   (None, 64, 64)       0           ['dropout_15[0][0]',
#                                                                   'add_14[0][0]']
#
#  add_31 (Add)                   (None, 64, 64)       0           ['dropout_31[0][0]',
#                                                                   'add_30[0][0]']
#
#  add_47 (Add)                   (None, 64, 64)       0           ['dropout_47[0][0]',
#                                                                   'add_46[0][0]']
#
#  add_63 (Add)                   (None, 64, 64)       0           ['dropout_63[0][0]',
#                                                                   'add_62[0][0]']
#
#  tf.stack (TFOpLambda)          (None, 64, 64, 4)    0           ['add_15[0][0]',
#                                                                   'add_31[0][0]',
#                                                                   'add_47[0][0]',
#                                                                   'add_63[0][0]']
#
#  tf.reshape_4 (TFOpLambda)      (None, 64, 64, 4)    0           ['tf.stack[0][0]']
#
#  reshape (Reshape)              (None, 4096, 4)      0           ['tf.reshape_4[0][0]']
#
#  lstm (LSTM)                    (None, 4096, 128)    68096       ['reshape[0][0]']
#
#  reshape_1 (Reshape)            (None, 64, 64, 128)  0           ['lstm[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 128, 128, 12  0           ['reshape_1[0][0]']
#                                 8)
#
#  conv2d (Conv2D)                (None, 128, 128, 1)  1153        ['up_sampling2d[0][0]']
#
# ==================================================================================================
# Total params: 4,935,553
# Trainable params: 4,935,553
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
optimizer = keras.optimizers.Adam(lr=0.0001)
model.compile(loss='binary_crossentropy',
              optimizer=optimizer)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
# Train the model
model.fit(x_train, y_train, batch_size=8, epochs=600)
# Out:
# Epoch 1/600
# 231/231 [==============================] - 93s 197ms/step - loss: 0.6776
# Epoch 2/600
# 231/231 [==============================] - 46s 199ms/step - loss: 0.6662
# Epoch 3/600
# 231/231 [==============================] - 46s 199ms/step - loss: 0.6652
# Epoch 4/600
# 231/231 [==============================] - 46s 199ms/step - loss: 0.6648
# Epoch 5/600
# 231/231 [==============================] - 46s 200ms/step - loss: 0.6645
# Epoch 6/600
# 231/231 [==============================] - 46s 198ms/step - loss: 0.6643
# Epoch 7/600
# 231/231 [==============================] - 46s 199ms/step - loss: 0.6641
# Epoch 8/600
# 231/231 [==============================] - 46s 198ms/step - loss: 0.6639
# Epoch 9/600
# 231/231 [==============================] - 45s 197ms/step - loss: 0.6638
# Epoch 10/600
# 231/231 [==============================] - 46s 197ms/step - loss: 0.6631
# Epoch 11/600
# 231/231 [==============================] - 46s 197ms/step - loss: 0.6624
# Epoch 12/600
# 231/231 [==============================] - 46s 197ms/step - loss: 0.6623
# Epoch 13/600
# 231/231 [==============================] - 46s 197ms/step - loss: 0.6619
# Epoch 14/600
# 231/231 [==============================] - 45s 197ms/step - loss: 0.6616
# Epoch 15/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6614
# Epoch 16/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6611
# Epoch 17/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6609
# Epoch 18/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6608
# Epoch 19/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6608
# Epoch 20/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6606
# Epoch 21/600
# 231/231 [==============================] - 45s 197ms/step - loss: 0.6605
# Epoch 22/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6603
# Epoch 23/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6602
# Epoch 24/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6600
# Epoch 25/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6598
# Epoch 26/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6597
# Epoch 27/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6596
# Epoch 28/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6595
# Epoch 29/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6593
# Epoch 30/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6593
# Epoch 31/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6592
# Epoch 32/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6591
# Epoch 33/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6591
# Epoch 34/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6590
# Epoch 35/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6589
# Epoch 36/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6589
# Epoch 37/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6588
# Epoch 38/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6587
# Epoch 39/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6587
# Epoch 40/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6586
# Epoch 41/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6585
# Epoch 42/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6585
# Epoch 43/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6584
# Epoch 44/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6584
# Epoch 45/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6583
# Epoch 46/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6584
# Epoch 47/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6583
# Epoch 48/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6582
# Epoch 49/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6582
# Epoch 50/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6582
# Epoch 51/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6582
# Epoch 52/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6581
# Epoch 53/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6580
# Epoch 54/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6580
# Epoch 55/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6580
# Epoch 56/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6580
# Epoch 57/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6579
# Epoch 58/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6579
# Epoch 59/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6579
# Epoch 60/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6578
# Epoch 61/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6578
# Epoch 62/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6578
# Epoch 63/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6578
# Epoch 64/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6578
# Epoch 65/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6577
# Epoch 66/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6577
# Epoch 67/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6577
# Epoch 68/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6576
# Epoch 69/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6577
# Epoch 70/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6576
# Epoch 71/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6576
# Epoch 72/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6575
# Epoch 73/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6576
# Epoch 74/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6575
# Epoch 75/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6575
# Epoch 76/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6575
# Epoch 77/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6575
# Epoch 78/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6575
# Epoch 79/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6574
# Epoch 80/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6574
# Epoch 81/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6574
# Epoch 82/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6574
# Epoch 83/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6574
# Epoch 84/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6574
# Epoch 85/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6573
# Epoch 86/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6573
# Epoch 87/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6573
# Epoch 88/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6573
# Epoch 89/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6573
# Epoch 90/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6573
# Epoch 91/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6572
# Epoch 92/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6572
# Epoch 93/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6572
# Epoch 94/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6572
# Epoch 95/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6572
# Epoch 96/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6572
# Epoch 97/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6572
# Epoch 98/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6572
# Epoch 99/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6572
# Epoch 100/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6571
# Epoch 101/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6571
# Epoch 102/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6571
# Epoch 103/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6571
# Epoch 104/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6571
# Epoch 105/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6571
# Epoch 106/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6571
# Epoch 107/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6570
# Epoch 108/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6570
# Epoch 109/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6570
# Epoch 110/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6570
# Epoch 111/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6570
# Epoch 112/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6570
# Epoch 113/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6570
# Epoch 114/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6570
# Epoch 115/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6569
# Epoch 116/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6569
# Epoch 117/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6569
# Epoch 118/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6569
# Epoch 119/600
# 231/231 [==============================] - 44s 192ms/step - loss: 0.6569
# Epoch 120/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6569
# Epoch 121/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6569
# Epoch 122/600
# 231/231 [==============================] - 44s 192ms/step - loss: 0.6569
# Epoch 123/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6569
# Epoch 124/600
# 231/231 [==============================] - 44s 192ms/step - loss: 0.6568
# Epoch 125/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6568
# Epoch 126/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6568
# Epoch 127/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6568
# Epoch 128/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6568
# Epoch 129/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6568
# Epoch 130/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6568
# Epoch 131/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6568
# Epoch 132/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6568
# Epoch 133/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6567
# Epoch 134/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6567
# Epoch 135/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6567
# Epoch 136/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6567
# Epoch 137/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6567
# Epoch 138/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6567
# Epoch 139/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6567
# Epoch 140/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6567
# Epoch 141/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6567
# Epoch 142/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6567
# Epoch 143/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6567
# Epoch 144/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6566
# Epoch 145/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6566
# Epoch 146/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6567
# Epoch 147/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6566
# Epoch 148/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6566
# Epoch 149/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6566
# Epoch 150/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6566
# Epoch 151/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6566
# Epoch 152/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6566
# Epoch 153/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6566
# Epoch 154/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6566
# Epoch 155/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6566
# Epoch 156/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6566
# Epoch 157/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6565
# Epoch 158/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6565
# Epoch 159/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6565
# Epoch 160/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6565
# Epoch 161/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6565
# Epoch 162/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6565
# Epoch 163/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6565
# Epoch 164/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6565
# Epoch 165/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6565
# Epoch 166/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6565
# Epoch 167/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6565
# Epoch 168/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6565
# Epoch 169/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6565
# Epoch 170/600
# 231/231 [==============================] - 44s 192ms/step - loss: 0.6564
# Epoch 171/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6565
# Epoch 172/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6564
# Epoch 173/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6564
# Epoch 174/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6564
# Epoch 175/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6564
# Epoch 176/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6564
# Epoch 177/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6564
# Epoch 178/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6564
# Epoch 179/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6564
# Epoch 180/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6564
# Epoch 181/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6564
# Epoch 182/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6564
# Epoch 183/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6564
# Epoch 184/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6563
# Epoch 185/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6563
# Epoch 186/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6563
# Epoch 187/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6563
# Epoch 188/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6563
# Epoch 189/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6563
# Epoch 190/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6563
# Epoch 191/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6563
# Epoch 192/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6563
# Epoch 193/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6563
# Epoch 194/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6563
# Epoch 195/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6563
# Epoch 196/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6563
# Epoch 197/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6563
# Epoch 198/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6563
# Epoch 199/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6563
# Epoch 200/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6563
# Epoch 201/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6562
# Epoch 202/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6562
# Epoch 203/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6562
# Epoch 204/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6562
# Epoch 205/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6562
# Epoch 206/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6562
# Epoch 207/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6562
# Epoch 208/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6562
# Epoch 209/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6562
# Epoch 210/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6562
# Epoch 211/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6562
# Epoch 212/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6562
# Epoch 213/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6562
# Epoch 214/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6562
# Epoch 215/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6562
# Epoch 216/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6562
# Epoch 217/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6561
# Epoch 218/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6561
# Epoch 219/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6561
# Epoch 220/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6561
# Epoch 221/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6561
# Epoch 222/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6561
# Epoch 223/600
# 231/231 [==============================] - 45s 196ms/step - loss: 0.6561
# Epoch 224/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6561
# Epoch 225/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6561
# Epoch 226/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6561
# Epoch 227/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6561
# Epoch 228/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6561
# Epoch 229/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6561
# Epoch 230/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6561
# Epoch 231/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6561
# Epoch 232/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6560
# Epoch 233/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6561
# Epoch 234/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6561
# Epoch 235/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6560
# Epoch 236/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6560
# Epoch 237/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6560
# Epoch 238/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6560
# Epoch 239/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6560
# Epoch 240/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6560
# Epoch 241/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6560
# Epoch 242/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6560
# Epoch 243/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6560
# Epoch 244/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6560
# Epoch 245/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6560
# Epoch 246/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6560
# Epoch 247/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6560
# Epoch 248/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6560
# Epoch 249/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6560
# Epoch 250/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6560
# Epoch 251/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6560
# Epoch 252/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6560
# Epoch 253/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6560
# Epoch 254/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6559
# Epoch 255/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6559
# Epoch 256/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6559
# Epoch 257/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6559
# Epoch 258/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6559
# Epoch 259/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6559
# Epoch 260/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6559
# Epoch 261/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6559
# Epoch 262/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6559
# Epoch 263/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6559
# Epoch 264/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6559
# Epoch 265/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6559
# Epoch 266/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6559
# Epoch 267/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6559
# Epoch 268/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6559
# Epoch 269/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6559
# Epoch 270/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6559
# Epoch 271/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6559
# Epoch 272/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6559
# Epoch 273/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6559
# Epoch 274/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6558
# Epoch 275/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6558
# Epoch 276/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6558
# Epoch 277/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6558
# Epoch 278/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6558
# Epoch 279/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6558
# Epoch 280/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6558
# Epoch 281/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6558
# Epoch 282/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6558
# Epoch 283/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6558
# Epoch 284/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6558
# Epoch 285/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6558
# Epoch 286/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6558
# Epoch 287/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6558
# Epoch 288/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6558
# Epoch 289/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6558
# Epoch 290/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6558
# Epoch 291/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6558
# Epoch 292/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6558
# Epoch 293/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6558
# Epoch 294/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6558
# Epoch 295/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6557
# Epoch 296/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6557
# Epoch 297/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6558
# Epoch 298/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6557
# Epoch 299/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6557
# Epoch 300/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6557
# Epoch 301/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6557
# Epoch 302/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6557
# Epoch 303/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6557
# Epoch 304/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6557
# Epoch 305/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6557
# Epoch 306/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6557
# Epoch 307/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6557
# Epoch 308/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6557
# Epoch 309/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6557
# Epoch 310/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6557
# Epoch 311/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6557
# Epoch 312/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6557
# Epoch 313/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6557
# Epoch 314/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6557
# Epoch 315/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6557
# Epoch 316/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6557
# Epoch 317/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6557
# Epoch 318/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6557
# Epoch 319/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6557
# Epoch 320/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6556
# Epoch 321/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6556
# Epoch 322/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6557
# Epoch 323/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6556
# Epoch 324/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6556
# Epoch 325/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6556
# Epoch 326/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6556
# Epoch 327/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6556
# Epoch 328/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6556
# Epoch 329/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6556
# Epoch 330/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6556
# Epoch 331/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6556
# Epoch 332/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6556
# Epoch 333/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6556
# Epoch 334/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6556
# Epoch 335/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6556
# Epoch 336/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6556
# Epoch 337/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6556
# Epoch 338/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6556
# Epoch 339/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6556
# Epoch 340/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6556
# Epoch 341/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6556
# Epoch 342/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6556
# Epoch 343/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6556
# Epoch 344/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6556
# Epoch 345/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6556
# Epoch 346/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6555
# Epoch 347/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6556
# Epoch 348/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6556
# Epoch 349/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6555
# Epoch 350/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6555
# Epoch 351/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6556
# Epoch 352/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6555
# Epoch 353/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6555
# Epoch 354/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6555
# Epoch 355/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6555
# Epoch 356/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6555
# Epoch 357/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6555
# Epoch 358/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6555
# Epoch 359/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6555
# Epoch 360/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6555
# Epoch 361/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6555
# Epoch 362/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6555
# Epoch 363/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6555
# Epoch 364/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6555
# Epoch 365/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6555
# Epoch 366/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6555
# Epoch 367/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6555
# Epoch 368/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6555
# Epoch 369/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6555
# Epoch 370/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6555
# Epoch 371/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6555
# Epoch 372/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6555
# Epoch 373/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6555
# Epoch 374/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6555
# Epoch 375/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6555
# Epoch 376/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6555
# Epoch 377/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6555
# Epoch 378/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6555
# Epoch 379/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6554
# Epoch 380/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6554
# Epoch 381/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6554
# Epoch 382/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6554
# Epoch 383/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6554
# Epoch 384/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6554
# Epoch 385/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6554
# Epoch 386/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6554
# Epoch 387/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6554
# Epoch 388/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6554
# Epoch 389/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6554
# Epoch 390/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6554
# Epoch 391/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6554
# Epoch 392/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6554
# Epoch 393/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6554
# Epoch 394/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6554
# Epoch 395/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6554
# Epoch 396/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6554
# Epoch 397/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6554
# Epoch 398/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6554
# Epoch 399/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6554
# Epoch 400/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6554
# Epoch 401/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6554
# Epoch 402/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6554
# Epoch 403/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6554
# Epoch 404/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6554
# Epoch 405/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6554
# Epoch 406/600
# 231/231 [==============================] - 44s 193ms/step - loss: 0.6554
# Epoch 407/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6554
# Epoch 408/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6554
# Epoch 409/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6554
# Epoch 410/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6554
# Epoch 411/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6554
# Epoch 412/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6554
# Epoch 413/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6554
# Epoch 414/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6554
# Epoch 415/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6554
# Epoch 416/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6553
# Epoch 417/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 418/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6553
# Epoch 419/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 420/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 421/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 422/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6553
# Epoch 423/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 424/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 425/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 426/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 427/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6553
# Epoch 428/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 429/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6553
# Epoch 430/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 431/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6553
# Epoch 432/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6553
# Epoch 433/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6553
# Epoch 434/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 435/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 436/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 437/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 438/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 439/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 440/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 441/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 442/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6553
# Epoch 443/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 444/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 445/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 446/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 447/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 448/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 449/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 450/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6553
# Epoch 451/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6553
# Epoch 452/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 453/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 454/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6552
# Epoch 455/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6553
# Epoch 456/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6552
# Epoch 457/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6553
# Epoch 458/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 459/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6552
# Epoch 460/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6552
# Epoch 461/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6552
# Epoch 462/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6552
# Epoch 463/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6552
# Epoch 464/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6553
# Epoch 465/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6552
# Epoch 466/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6552
# Epoch 467/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6552
# Epoch 468/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6552
# Epoch 469/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6552
# Epoch 470/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6552
# Epoch 471/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6552
# Epoch 472/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6552
# Epoch 473/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6552
# Epoch 474/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6552
# Epoch 475/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6552
# Epoch 476/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6552
# Epoch 477/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6552
# Epoch 478/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6552
# Epoch 479/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6552
# Epoch 480/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6552
# Epoch 481/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6552
# Epoch 482/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6552
# Epoch 483/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6552
# Epoch 484/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6552
# Epoch 485/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6552
# Epoch 486/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6552
# Epoch 487/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6552
# Epoch 488/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6552
# Epoch 489/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6552
# Epoch 490/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6552
# Epoch 491/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6552
# Epoch 492/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6552
# Epoch 493/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6552
# Epoch 494/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6552
# Epoch 495/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6552
# Epoch 496/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6552
# Epoch 497/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6552
# Epoch 498/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6552
# Epoch 499/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6552
# Epoch 500/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6552
# Epoch 501/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6552
# Epoch 502/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6552
# Epoch 503/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6552
# Epoch 504/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6552
# Epoch 505/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6552
# Epoch 506/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 507/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 508/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 509/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 510/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 511/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6551
# Epoch 512/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6551
# Epoch 513/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 514/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 515/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 516/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 517/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 518/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6551
# Epoch 519/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 520/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 521/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 522/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 523/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 524/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 525/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6551
# Epoch 526/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 527/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 528/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 529/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6551
# Epoch 530/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 531/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 532/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 533/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6551
# Epoch 534/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 535/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 536/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6551
# Epoch 537/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 538/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 539/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 540/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6551
# Epoch 541/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 542/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6551
# Epoch 543/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 544/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 545/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 546/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6551
# Epoch 547/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6551
# Epoch 548/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 549/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6551
# Epoch 550/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 551/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 552/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 553/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6551
# Epoch 554/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 555/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 556/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 557/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6551
# Epoch 558/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 559/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 560/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6551
# Epoch 561/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 562/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6551
# Epoch 563/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6550
# Epoch 564/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6551
# Epoch 565/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6551
# Epoch 566/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6551
# Epoch 567/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6550
# Epoch 568/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6550
# Epoch 569/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6550
# Epoch 570/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6550
# Epoch 571/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6550
# Epoch 572/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6550
# Epoch 573/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6550
# Epoch 574/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6550
# Epoch 575/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6550
# Epoch 576/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6550
# Epoch 577/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6550
# Epoch 578/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6550
# Epoch 579/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6550
# Epoch 580/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6550
# Epoch 581/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6550
# Epoch 582/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6550
# Epoch 583/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6550
# Epoch 584/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6550
# Epoch 585/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6550
# Epoch 586/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6550
# Epoch 587/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6550
# Epoch 588/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6550
# Epoch 589/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6550
# Epoch 590/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6550
# Epoch 591/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6550
# Epoch 592/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6550
# Epoch 593/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6550
# Epoch 594/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6550
# Epoch 595/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6550
# Epoch 596/600
# 231/231 [==============================] - 45s 193ms/step - loss: 0.6550
# Epoch 597/600
# 231/231 [==============================] - 45s 195ms/step - loss: 0.6550
# Epoch 598/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6550
# Epoch 599/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6550
# Epoch 600/600
# 231/231 [==============================] - 45s 194ms/step - loss: 0.6550

# %%
# Evaluate the model on test data
loss = model.evaluate(x_test, y_test, verbose=0)
print(loss )
# Out:
# 0.6484830975532532

# %%
predictions_transformer = model.predict(x_test)
# Out:
# 39/39 [==============================] - 10s 117ms/step

# %%
# Save the trained model
model.save('transformer_model.h5')
